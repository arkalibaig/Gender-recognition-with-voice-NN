# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
gender_voices = pd.read_csv("vocal_gender_features_new.csv")

# %%
gender_voices.head()
# Out:
#    mean_spectral_centroid  std_spectral_centroid  mean_spectral_bandwidth  \
# 0             2247.331739            1158.537748              1870.415462
# 1             1790.719889             996.554825              1757.898617
# 2             1977.923363            1010.148667              1747.099555
# 3             2037.765550            1311.440630              1745.224852
# 4             1739.383829            1092.623322              1623.135563
#
#    std_spectral_bandwidth  mean_spectral_contrast  mean_spectral_flatness  \
# 0              370.405241               21.440710                0.036879
# 1              410.710318               21.513383                0.018936
# 2              461.458379               20.476283                0.032616
# 3              419.056484               19.516014                0.028482
# 4              450.088465               20.260620                0.025737
#
#    mean_spectral_rolloff  zero_crossing_rate  rms_energy  mean_pitch  ...  \
# 0            4419.438073            0.169241    0.082552   1592.1033  ...
# 1            3635.742188            0.108068    0.055477   1112.6351  ...
# 2            3873.291016            0.144633    0.060388   1557.5225  ...
# 3            3826.584507            0.148933    0.029559   1481.0868  ...
# 4            3452.903892            0.117961    0.069078   1424.5352  ...
#
#    mfcc_9_std  mfcc_10_mean  mfcc_10_std  mfcc_11_mean  mfcc_11_std  \
# 0   21.736240      2.303085     8.983318    -17.410305     9.115154
# 1   13.937135     -0.953942    10.831742     -0.088775    10.297690
# 2   14.900779      0.260098    14.031009     -0.420670    10.810292
# 3   15.957924     -1.486122    14.461978     -8.479608    12.550333
# 4   15.105562     -3.366364    13.943447     -6.561539    11.944948
#
#    mfcc_12_mean  mfcc_12_std  mfcc_13_mean  mfcc_13_std  label
# 0      0.301804    10.452693     -3.080832    10.146248      0
# 1     -7.281142    10.926579     -0.450248     8.489134      0
# 2     -0.199829    11.986182      3.372986     9.285437      0
# 3      3.997028     9.912608     -6.946966    10.574301      0
# 4      1.410639    13.110976     -3.252258     9.866687      0
#
# [5 rows x 44 columns]

# %%
X = gender_voices.drop(columns=["label"]).values
Y = gender_voices["label"].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size= 0.2, random_state = 42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
model =Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(128 , activation = "relu"),
    Dense(64, activation='relu'),
    Dense(1, activation = 'sigmoid')])
model.compile( optimizer= 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9518 - loss: 0.1322 - val_accuracy: 0.9978 - val_loss: 0.0067
# Epoch 2/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9990 - loss: 0.0043 - val_accuracy: 0.9988 - val_loss: 0.0033
# Epoch 3/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9997 - val_loss: 0.0019
# Epoch 4/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 3.0842e-04 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 5/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.6306e-04 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 6/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 1.0000 - loss: 1.0393e-04 - val_accuracy: 0.9997 - val_loss: 0.0017
# Epoch 7/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 7.4006e-05 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 8/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.0513e-05 - val_accuracy: 0.9997 - val_loss: 0.0019
# Epoch 9/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 3.7684e-05 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 10/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.6562e-05 - val_accuracy: 0.9997 - val_loss: 0.0019
# Epoch 11/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 2.0045e-05 - val_accuracy: 0.9997 - val_loss: 0.0019
# Epoch 12/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.8519e-05 - val_accuracy: 0.9997 - val_loss: 0.0019
# Epoch 13/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2038e-05 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 14/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.0566e-05 - val_accuracy: 0.9997 - val_loss: 0.0021
# Epoch 15/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.5744e-06 - val_accuracy: 0.9997 - val_loss: 0.0022
# Epoch 16/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.8228e-06 - val_accuracy: 0.9997 - val_loss: 0.0022
# Epoch 17/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.0307e-06 - val_accuracy: 0.9997 - val_loss: 0.0022
# Epoch 18/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.3414e-06 - val_accuracy: 0.9997 - val_loss: 0.0024
# Epoch 19/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.2679e-06 - val_accuracy: 0.9997 - val_loss: 0.0023
# Epoch 20/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.5881e-06 - val_accuracy: 0.9997 - val_loss: 0.0025

# %%
loss, acc = model.evaluate(X_test, Y_test)
print(f"Test Accuracy:{acc:4f}")
# Out:
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0053
# Test Accuracy:0.999690
